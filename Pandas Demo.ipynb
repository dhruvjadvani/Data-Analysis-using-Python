# %%
import pandas as pd
df=pd.read_csv('C:/Users/Manish/Desktop/Data Analysis py/survey data 2020/survey_results_public.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# 5               6                     I am a developer by profession       No
# 6               7                     I am a developer by profession      Yes
# 7               8                     I am a developer by profession      Yes
# 8               9                     I am a developer by profession       No
# 9              10                     I am a developer by profession      Yes
# 10             11                     I am a developer by profession      Yes
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
# Respondent                      64461 non-null int64
# MainBranch                      64162 non-null object
# Hobbyist                        64416 non-null object
# Age                             45446 non-null float64
# Age1stCode                      57900 non-null object
# CompFreq                        40069 non-null object
# CompTotal                       34826 non-null float64
# ConvertedComp                   34756 non-null float64
# Country                         64072 non-null object
# CurrencyDesc                    45472 non-null object
# CurrencySymbol                  45472 non-null object
# DatabaseDesireNextYear          44070 non-null object
# DatabaseWorkedWith              49537 non-null object
# DevType                         49370 non-null object
# EdLevel                         57431 non-null object
# ...

# %%
pd.set_option('display.max_columns',61)
pd.set_option('display.max_rows',61)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# 5               6                     I am a developer by profession       No
# 6               7                     I am a developer by profession      Yes
# 7               8                     I am a developer by profession      Yes
# 8               9                     I am a developer by profession       No
# 9              10                     I am a developer by profession      Yes
# 10             11                     I am a developer by profession      Yes
# ...

# %%
schema_df=pd.read_csv('C:/Users/Manish/Desktop/Data Analysis py/survey data 2020/survey_results_schema.csv')

# %%
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
pd.set_option('display.max_rows',61)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# 5               6                     I am a developer by profession       No
# 6               7                     I am a developer by profession      Yes
# 7               8                     I am a developer by profession      Yes
# 8               9                     I am a developer by profession       No
# 9              10                     I am a developer by profession      Yes
# 10             11                     I am a developer by profession      Yes
# ...

# %%
pd.set_option('display.max_rows',61)
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# ...

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64451       64104        NaN      Yes  NaN         19      NaN        NaN
# 64452       64236        NaN      Yes  NaN        NaN      NaN        NaN
# 64453       64330        NaN      Yes  NaN          5      NaN        NaN
# 64454       64480        NaN      Yes  NaN         21      NaN        NaN
# 64455       64567        NaN      Yes  NaN        NaN      NaN        NaN
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc CurrencySymbol  \
# 64451            NaN         Poland          NaN            NaN
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df[ 'Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
# 5         No
# 6        Yes
# 7        Yes
# 8         No
# 9        Yes
# 10       Yes
# 11        No
# 12       Yes
# 13       Yes
# 14       Yes
# 15       Yes
# 16       Yes
# 17       Yes
# 18        No
# 19       Yes
# 20       Yes
# 21       Yes
# 22       Yes
# 23       Yes
# 24        No
# 25        No
# 26       Yes
# 27       Yes
# 28       Yes
# 29       Yes
#         ...
# 64431    Yes
# 64432    Yes
# 64433    Yes
# 64434     No
# 64435    Yes
# 64436    Yes
# 64437    Yes
# 64438    Yes
# 64439    Yes
# 64440     No
# 64441    Yes
# 64442    Yes
# 64443    Yes
# 64444    Yes
# 64445    Yes
# 64446    Yes
# 64447    Yes
# 64448    Yes
# 64449    Yes
# 64450    Yes
# 64451    Yes
# 64452    Yes
# 64453    Yes
# 64454    Yes
# 64455    Yes
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df[ 'Hobbyist'].count
# Out:
# <bound method Series.count of 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
# 5         No
# 6        Yes
# 7        Yes
# 8         No
# 9        Yes
# 10       Yes
# 11        No
# 12       Yes
# 13       Yes
# 14       Yes
# 15       Yes
# 16       Yes
# 17       Yes
# 18        No
# 19       Yes
# 20       Yes
# 21       Yes
# 22       Yes
# 23       Yes
# 24        No
# 25        No
# 26       Yes
# 27       Yes
# 28       Yes
# 29       Yes
#         ...
# 64431    Yes
# 64432    Yes
# 64433    Yes
# 64434     No
# 64435    Yes
# 64436    Yes
# 64437    Yes
# 64438    Yes
# 64439    Yes
# 64440     No
# 64441    Yes
# 64442    Yes
# 64443    Yes
# 64444    Yes
# 64445    Yes
# 64446    Yes
# 64447    Yes
# 64448    Yes
# 64449    Yes
# 64450    Yes
# 64451    Yes
# 64452    Yes
# 64453    Yes
# 64454    Yes
# 64455    Yes
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object>

# %%
df[ 'Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.loc[0]
# Out:
# Respondent                                                                      1
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     13
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Germany
# CurrencyDesc                                                        European Euro
# CurrencySymbol                                                                EUR
# ...

# %%
df.loc[0,'Hobbyist']
# Out:
# 'Yes'

# %%
df.loc[[0,1,2],'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0:2,'Hobbyist'] #slicing
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0:2, 'Hobbyist':'ConvertedComp']
# Out:
#   Hobbyist  Age Age1stCode CompFreq  CompTotal  ConvertedComp
# 0      Yes  NaN         13  Monthly        NaN            NaN
# 1       No  NaN         19      NaN        NaN            NaN
# 2      Yes  NaN         15      NaN        NaN            NaN

# %%
df.loc[1]
# Out:
# Respondent                                                                      2
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                       No
# Age                                                                           NaN
# Age1stCode                                                                     19
# CompFreq                                                                      NaN
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                            United Kingdom
# CurrencyDesc                                                       Pound sterling
# CurrencySymbol                                                                GBP
# ...

# %%
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
Schema_df=pd.read_csv('C:/Users/Manish/Desktop/Data Analysis py/survey data 2020/survey_results_schema.csv',index_col='Column')
Schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
Schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
Schema_df.loc['Hobbyist','QuestionText']
# Out:
# 'Do you code as a hobby?'

# %%
Schema_df.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
Schema_df.sort_index(ascending=False)
# Out:
#                                                                    QuestionText
# Column
# YearsCodePro                  NOT including education, how many years have y...
# YearsCode                     Including any education, how many years have y...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# UndergradMajor                            What was your primary field of study?
# Trans                                                      Are you transgender?
# SurveyLength                  How do you feel about the length of the survey...
# SurveyEase                    How easy or difficult was this survey to compl...
# Sexuality                     Which of the following describe you, if any? P...
# ...

# %%
Schema_df.sort_index(ascending=True)
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
Schema_df.sort_index(inplace=True)

# %%
Schema_df
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
high_salary=(df['ConvertedComp']>70000)

# %%
df.loc[high_salary]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 7               8                     I am a developer by profession      Yes
# 15             16                     I am a developer by profession      Yes
# 16             17                     I am a developer by profession      Yes
# 17             18                     I am a developer by profession      Yes
# 18             19                     I am a developer by profession       No
# 23             24                     I am a developer by profession      Yes
# 25             26                     I am a developer by profession       No
# 35             36  I am not primarily a developer, but I write co...      Yes
# 37             38                     I am a developer by profession       No
# 40             41                     I am a developer by profession       No
# 41             42                     I am a developer by profession       No
# ...

# %%
df.loc[high_salary,['Country','DatabaseWorkedWith','LanguageWorkedWith','ConvertedComp']]
# Out:
#               Country                                 DatabaseWorkedWith  \
# 7       United States                                MariaDB;MySQL;Redis
# 15     United Kingdom                                         PostgreSQL
# 16      United States                    Microsoft SQL Server;PostgreSQL
# 17      United States           Elasticsearch;MariaDB;MySQL;Redis;SQLite
# 18      United States                       MariaDB;Microsoft SQL Server
# 23            Germany                                  PostgreSQL;SQLite
# 25             Canada                                         PostgreSQL
# 35     United Kingdom        IBM DB2;Microsoft SQL Server;MongoDB;SQLite
# 37              Italy                           MongoDB;PostgreSQL;Redis
# 40      United States                               Microsoft SQL Server
# 41      United States            Microsoft SQL Server;MySQL;Oracle;Redis
# 42      United States                                             Oracle
# ...

# %%
countries=['United States','United Kingdom','Canada','Germany','India']
filt=df['Country'].isin(countries)

# %%
df.loc[filt,'Country']
# Out:
# 0               Germany
# 1        United Kingdom
# 4         United States
# 5               Germany
# 6                 India
# 7         United States
# 9        United Kingdom
# 10       United Kingdom
# 13        United States
# 15       United Kingdom
# 16        United States
# 17        United States
# 18        United States
# 21                India
# 22              Germany
# 23              Germany
# 25               Canada
# 26        United States
# 29       United Kingdom
# 31               Canada
# 33              Germany
# 34        United States
# 35       United Kingdom
# 38       United Kingdom
# 39        United States
# 40        United States
# 41        United States
# 42        United States
# 46       United Kingdom
# 47        United States
#               ...
# 64337             India
# 64340     United States
# 64347     United States
# 64350             India
# 64352     United States
# 64354     United States
# 64356     United States
# ...

# %%
df['LanguageWorkedWith']
# Out:
# 0                                   C#;HTML/CSS;JavaScript
# 1                                         JavaScript;Swift
# 2                                 Objective-C;Python;Swift
# 3                                                      NaN
# 4                                        HTML/CSS;Ruby;SQL
# 5                                 HTML/CSS;Java;JavaScript
# 6                                          C#;HTML/CSS;PHP
# 7                                               Python;SQL
# 8                                  HTML/CSS;JavaScript;PHP
# 9                      HTML/CSS;Java;JavaScript;Python;SQL
# 10                                     C#;JavaScript;Swift
# 11                                     HTML/CSS;JavaScript
# 12                                     C;JavaScript;Python
# 13                      HTML/CSS;JavaScript;SQL;TypeScript
# 14        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
# 15       Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# ...

# %%
filt=df['LanguageWorkedWith'].str.contains('Python', na='False')

# %%
df.loc[filt,'LanguageWorkedWith']
# Out:
# C:\Users\Manish\Anaconda3\lib\site-packages\pandas\core\indexing.py:1017: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# False    C#;HTML/CSS;JavaScript
# False    C#;HTML/CSS;JavaScript
# True           JavaScript;Swift
# False                       NaN
# False    C#;HTML/CSS;JavaScript
# False    C#;HTML/CSS;JavaScript
# False    C#;HTML/CSS;JavaScript
# True           JavaScript;Swift
# False    C#;HTML/CSS;JavaScript
# True           JavaScript;Swift
# False    C#;HTML/CSS;JavaScript
# False    C#;HTML/CSS;JavaScript
# True           JavaScript;Swift
# False    C#;HTML/CSS;JavaScript
# True           JavaScript;Swift
# False    C#;HTML/CSS;JavaScript
# True           JavaScript;Swift
# ...

# %%
filt
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
# 5        False
# 6        False
# 7         True
# 8        False
# 9         True
# 10       False
# 11       False
# 12        True
# 13       False
# 14        True
# 15       False
# 16        True
# 17       False
# 18       False
# 19       False
# 20       False
# 21        True
# 22       False
# 23       False
# 24       False
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 64431    False
# 64432     True
# 64433     True
# 64434    False
# 64435    False
# 64436    False
# 64437    False
# 64438     True
# 64439    False
# 64440    False
# 64441    False
# 64442    False
# 64443     True
# 64444    False
# 64445    False
# 64446     True
# 64447    False
# 64448    False
# 64449    False
# 64450    False
# 64451    False
# 64452    False
# 64453    False
# 64454    False
# 64455    False
# 64456    False
# 64457     True
# ...

# %%
df.loc[filt]
# Out:
# C:\Users\Manish\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#        Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# False         1.0  I am a developer by profession      Yes  NaN         13
# False         1.0  I am a developer by profession      Yes  NaN         13
# True          2.0  I am a developer by profession       No  NaN         19
# False         NaN                             NaN      NaN  NaN        NaN
# False         1.0  I am a developer by profession      Yes  NaN         13
# False         1.0  I am a developer by profession      Yes  NaN         13
# ...

# %%
df.rename(columns={'ConvertedComp':'SalaryUSD'},inplace='True')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# 5               6                     I am a developer by profession       No
# 6               7                     I am a developer by profession      Yes
# 7               8                     I am a developer by profession      Yes
# 8               9                     I am a developer by profession       No
# 9              10                     I am a developer by profession      Yes
# 10             11                     I am a developer by profession      Yes
# ...

# %%
df['SalaryUSD']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7         116000.0
# 8              NaN
# 9          32315.0
# 10         40070.0
# 11         14268.0
# 12         38916.0
# 13         66000.0
# 14             NaN
# 15        108576.0
# 16         79000.0
# 17       1260000.0
# 18         83400.0
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23         91883.0
# 24             NaN
# 25         71093.0
# 26             NaN
# 27             NaN
# 28             NaN
# 29         38778.0
#            ...
# 64431          NaN
# 64432          NaN
# 64433          NaN
# 64434          NaN
# 64435          NaN
# 64436          NaN
# 64437          NaN
# 64438          NaN
# 64439          NaN
# 64440          NaN
# 64441          NaN
# 64442          NaN
# 64443          NaN
# 64444          NaN
# 64445          NaN
# 64446          NaN
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
# 5         No
# 6        Yes
# 7        Yes
# 8         No
# 9        Yes
# 10       Yes
# 11        No
# 12       Yes
# 13       Yes
# 14       Yes
# 15       Yes
# 16       Yes
# 17       Yes
# 18        No
# 19       Yes
# 20       Yes
# 21       Yes
# 22       Yes
# 23       Yes
# 24        No
# 25        No
# 26       Yes
# 27       Yes
# 28       Yes
# 29       Yes
#         ...
# 64431    Yes
# 64432    Yes
# 64433    Yes
# 64434     No
# 64435    Yes
# 64436    Yes
# 64437    Yes
# 64438    Yes
# 64439    Yes
# 64440     No
# 64441    Yes
# 64442    Yes
# 64443    Yes
# 64444    Yes
# 64445    Yes
# 64446    Yes
# 64447    Yes
# 64448    Yes
# 64449    Yes
# 64450    Yes
# 64451    Yes
# 64452    Yes
# 64453    Yes
# 64454    Yes
# 64455    Yes
# 64456    Yes
# 64457    Yes
# 64458    Yes
# 64459    Yes
# 64460    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].map({'Yes':True, 'No':False})
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
# 5        False
# 6         True
# 7         True
# 8        False
# 9         True
# 10        True
# 11       False
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18       False
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24       False
# 25       False
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 64431     True
# 64432     True
# 64433     True
# 64434    False
# 64435     True
# 64436     True
# 64437     True
# 64438     True
# 64439     True
# 64440    False
# 64441     True
# 64442     True
# 64443     True
# 64444     True
# 64445     True
# 64446     True
# 64447     True
# 64448     True
# 64449     True
# 64450     True
# 64451     True
# 64452     True
# 64453     True
# 64454     True
# 64455     True
# 64456     True
# 64457     True
# ...

# %%
df['Hobbyist']=df['Hobbyist'].map({'Yes':True, 'No':False})

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession     True
# 1               2                     I am a developer by profession    False
# 2               3                        I code primarily as a hobby     True
# 3               4                     I am a developer by profession     True
# 4               5  I used to be a developer by profession, but no...     True
# 5               6                     I am a developer by profession    False
# 6               7                     I am a developer by profession     True
# 7               8                     I am a developer by profession     True
# 8               9                     I am a developer by profession    False
# 9              10                     I am a developer by profession     True
# 10             11                     I am a developer by profession     True
# ...

# %%
df.sort_values(by='Country', inplace=True)

# %%
df['Country'].head(50)
# Out:
# 8599     Afghanistan
# 24908    Afghanistan
# 57044    Afghanistan
# 41950    Afghanistan
# 50469    Afghanistan
# 37601    Afghanistan
# 28270    Afghanistan
# 7586     Afghanistan
# 43157    Afghanistan
# 61453    Afghanistan
# 50492    Afghanistan
# 36354    Afghanistan
# 43140    Afghanistan
# 63925    Afghanistan
# 38261    Afghanistan
# 35602    Afghanistan
# 43010    Afghanistan
# 36887    Afghanistan
# 43708    Afghanistan
# 35541    Afghanistan
# 64306    Afghanistan
# 43709    Afghanistan
# 23708    Afghanistan
# 41506    Afghanistan
# 63993    Afghanistan
# 43843    Afghanistan
# 59329    Afghanistan
# 895      Afghanistan
# 50847    Afghanistan
# 35052    Afghanistan
# 2918     Afghanistan
# 53923    Afghanistan
# 15371    Afghanistan
# 45879    Afghanistan
# 44571    Afghanistan
# 50812    Afghanistan
# 62520    Afghanistan
# 35511    Afghanistan
# 33755    Afghanistan
# 26477    Afghanistan
# 37284    Afghanistan
# 9806     Afghanistan
# 56146    Afghanistan
# ...

# %%
df[['Country','SalaryUSD']].head(50)
# Out:
#            Country  SalaryUSD
# 8599   Afghanistan        NaN
# 24908  Afghanistan        NaN
# 57044  Afghanistan        NaN
# 41950  Afghanistan        NaN
# 50469  Afghanistan    20220.0
# 37601  Afghanistan        NaN
# 28270  Afghanistan   130000.0
# 7586   Afghanistan        NaN
# 43157  Afghanistan        NaN
# 61453  Afghanistan        NaN
# 50492  Afghanistan        NaN
# 36354  Afghanistan        NaN
# 43140  Afghanistan        NaN
# 63925  Afghanistan  1000000.0
# 38261  Afghanistan   231192.0
# 35602  Afghanistan      780.0
# 43010  Afghanistan        NaN
# 36887  Afghanistan        NaN
# 43708  Afghanistan        NaN
# 35541  Afghanistan        NaN
# 64306  Afghanistan        NaN
# 43709  Afghanistan        NaN
# 23708  Afghanistan        NaN
# 41506  Afghanistan        NaN
# 63993  Afghanistan  1000000.0
# 43843  Afghanistan        NaN
# 59329  Afghanistan        NaN
# 895    Afghanistan        NaN
# 50847  Afghanistan        NaN
# 35052  Afghanistan        NaN
# ...

# %%
df.sort_values(by=['Country','SalaryUSD'],ascending=[True,False], inplace=True)

# %%
df[['Country','SalaryUSD']].head(50)
# Out:
#            Country  SalaryUSD
# 63925  Afghanistan  1000000.0
# 63993  Afghanistan  1000000.0
# 61540  Afghanistan  1000000.0
# 38261  Afghanistan   231192.0
# 28270  Afghanistan   130000.0
# 62520  Afghanistan    23328.0
# 9806   Afghanistan    23328.0
# 50812  Afghanistan    20950.0
# 50469  Afghanistan    20220.0
# 43642  Afghanistan    18660.0
# 15371  Afghanistan    18000.0
# 2918   Afghanistan    16335.0
# 26443  Afghanistan    13992.0
# 56146  Afghanistan    10884.0
# 26676  Afghanistan     8016.0
# 30451  Afghanistan     5448.0
# 30405  Afghanistan     4668.0
# 28704  Afghanistan     4509.0
# 34842  Afghanistan     4356.0
# 26758  Afghanistan     2328.0
# 33755  Afghanistan     1860.0
# 35602  Afghanistan      780.0
# 17985  Afghanistan      109.0
# 35168  Afghanistan        0.0
# 8599   Afghanistan        NaN
# 24908  Afghanistan        NaN
# 57044  Afghanistan        NaN
# 41950  Afghanistan        NaN
# 37601  Afghanistan        NaN
# 7586   Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# 53175    2000000.0
# 5701     2000000.0
# 42657    2000000.0
# 58136    2000000.0
# 45753    2000000.0
# 1784     2000000.0
# 3058     2000000.0
# 3031     2000000.0
# 1407     2000000.0
# 3247     2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10,'SalaryUSD')
# Out:
#        Respondent                      MainBranch Hobbyist   Age  \
# 53175       54263  I am a developer by profession     True  29.0
# 5701         5725  I am a developer by profession    False  26.0
# 42657       43430  I am a developer by profession     True  33.0
# 58136       59279  I am a developer by profession     True   NaN
# 45753       46711  I am a developer by profession     True   NaN
# 1784         1793  I am a developer by profession     True  27.0
# 3058         3072  I am a developer by profession     True  32.0
# 3031         3045  I am a developer by profession     True  35.0
# 1407         1413  I am a developer by profession     True  25.0
# 3247         3261  I am a developer by profession     True  34.0
#
#                  Age1stCode CompFreq     CompTotal  SalaryUSD        Country  \
# 53175                    10   Weekly  7.000000e+04  2000000.0         Canada
# 5701                     14  Monthly  1.800000e+05  2000000.0         Canada
# ...

# %%
df['SalaryUSD'].head(15)
# Out:
# 63925    1000000.0
# 63993    1000000.0
# 61540    1000000.0
# 38261     231192.0
# 28270     130000.0
# 62520      23328.0
# 9806       23328.0
# 50812      20950.0
# 50469      20220.0
# 43642      18660.0
# 15371      18000.0
# 2918       16335.0
# 26443      13992.0
# 56146      10884.0
# 26676       8016.0
# Name: SalaryUSD, dtype: float64
